# %%
# !pip install roboflow
# !pip install ultralytics==8.0.196

# %%
from roboflow import Roboflow
from ultralytics import YOLO, settings
import yaml

# %%
rf = Roboflow(api_key="uU79vf8s9NUST3y2r3vl")
project = rf.workspace("boda-nqwrc").project("bodaboda-5str8")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to bodaboda-3 in yolov8:: 100%|██████████| 3833/3833 [00:00<00:00, 5019.46it/s]

# %%
settings['datasets_dir'] = '/content/'
settings.update()
settings
# Out:
# {'settings_version': '0.0.4',
#  'datasets_dir': '/content/',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True}

# %%
model= YOLO(model='yolov8n-pose')
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 18.2MB/s]

# %%
model.train(data='/content/bodaboda-3/data.yaml',
            epochs=1,
            patience=15,
            pretrained=True,
            verbose=True,
            seed=2023,
            save_dir='/content/',
            device = 'cuda'
            )
# Out:
# New https://pypi.org/project/ultralytics/8.2.50 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
